# %% [markdown]
# # Obtención de los datos de calidad del aire

# %%
import os
import requests
import zipfile
import glob
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Extracción desde la web del Portal de datos abiertos del Ayuntamiento de Madrid

# %%
data_folder = {
    "estaciones": "datos/estaciones",
    "diarios": "datos/diarios",
    "horarios": "datos/horarios",
}

data_url = "https://datos.madrid.es/egob/catalogo/"

mediciones_estaciones = [
    "212629-1-estaciones-control-aire.csv"
]

mediciones_diarias = [
    "201410-10306615-calidad-aire-diario.csv",
    "201410-10306612-calidad-aire-diario.csv",
    "201410-10306609-calidad-aire-diario.csv",
    "201410-10306606-calidad-aire-diario.csv",
    "201410-7775096-calidad-aire-diario.csv",
    "201410-7775098-calidad-aire-diario.csv",
    "201410-10306574-calidad-aire-diario.csv",
    "201410-10306576-calidad-aire-diario.csv",
    "201410-10306578-calidad-aire-diario.csv",
    "201410-10306580-calidad-aire-diario.csv",
    "201410-10306582-calidad-aire-diario.csv",
    "201410-10306584-calidad-aire-diario.csv",
    "201410-10306586-calidad-aire-diario.csv",
    "201410-10306588-calidad-aire-diario.csv",
    "201410-10306590-calidad-aire-diario.csv",
    "201410-10306592-calidad-aire-diario.csv",
    "201410-10306594-calidad-aire-diario.csv",
    "201410-10306596-calidad-aire-diario.csv",
    "201410-10306598-calidad-aire-diario.csv",
    "201410-10306600-calidad-aire-diario.csv",
    "201410-10306602-calidad-aire-diario.csv",
    "201410-10306604-calidad-aire-diario.csv",
]

mediciones_hora = [
    "201200-10306318-calidad-aire-horario.zip",
    "201200-10306317-calidad-aire-horario.zip",
    "201200-10306316-calidad-aire-horario.zip",
    "201200-42-calidad-aire-horario.zip",
    "201200-10306314-calidad-aire-horario.zip",
    "201200-10306313-calidad-aire-horario.zip",
    "201200-28-calidad-aire-horario.zip",
    "201200-27-calidad-aire-horario.zip",
    "201200-26-calidad-aire-horario.zip",
    "201200-23-calidad-aire-horario.zip",
    "201200-22-calidad-aire-horario.zip",
    "201200-21-calidad-aire-horario.zip",
    "201200-20-calidad-aire-horario.zip",
    "201200-19-calidad-aire-horario.zip",
    "201200-18-calidad-aire-horario.zip",
    "201200-17-calidad-aire-horario.zip",
    "201200-16-calidad-aire-horario.zip",
    "201200-15-calidad-aire-horario.zip",
    "201200-14-calidad-aire-horario.zip",
    "201200-13-calidad-aire-horario.zip",
    "201200-30-calidad-aire-horario.zip",
    "201200-29-calidad-aire-horario.zip",
]

# %%
def download_file(data_url, file, data_folder):
    url = os.path.join(data_url + file)
    filename = os.path.join(data_folder, file)
    
    r = requests.get(url, allow_redirects=True)
    open(filename, "wb").write(r.content)
    
    print(f"Downloaded {file}")

# %%
for _, folder in data_folder.items():
    if not os.path.exists(folder):
        os.mkdir(folder)

# Descarga estaciones de medición
for file in mediciones_estaciones:
    download_file(data_url, file, data_folder["estaciones"])    

# Descarga mediciones diarias
for file in mediciones_diarias:
    download_file(data_url, file, data_folder["diarios"])    

# Descarga mediciones hora
for file in mediciones_hora:
    download_file(data_url, file, data_folder["horarios"])
# Out:
# Downloaded 212629-1-estaciones-control-aire.csv
# Downloaded 201410-10306615-calidad-aire-diario.csv
# Downloaded 201410-10306612-calidad-aire-diario.csv
# Downloaded 201410-10306609-calidad-aire-diario.csv
# Downloaded 201410-10306606-calidad-aire-diario.csv
# Downloaded 201410-7775096-calidad-aire-diario.csv
# Downloaded 201410-7775098-calidad-aire-diario.csv
# Downloaded 201410-10306574-calidad-aire-diario.csv
# Downloaded 201410-10306576-calidad-aire-diario.csv
# Downloaded 201410-10306578-calidad-aire-diario.csv
# Downloaded 201410-10306580-calidad-aire-diario.csv
# Downloaded 201410-10306582-calidad-aire-diario.csv
# Downloaded 201410-10306584-calidad-aire-diario.csv
# Downloaded 201410-10306586-calidad-aire-diario.csv
# Downloaded 201410-10306588-calidad-aire-diario.csv
# Downloaded 201410-10306590-calidad-aire-diario.csv
# Downloaded 201410-10306592-calidad-aire-diario.csv
# Downloaded 201410-10306594-calidad-aire-diario.csv
# Downloaded 201410-10306596-calidad-aire-diario.csv
# Downloaded 201410-10306598-calidad-aire-diario.csv
# Downloaded 201410-10306600-calidad-aire-diario.csv
# Downloaded 201410-10306602-calidad-aire-diario.csv
# Downloaded 201410-10306604-calidad-aire-diario.csv
# Downloaded 201200-10306318-calidad-aire-horario.zip
# Downloaded 201200-10306317-calidad-aire-horario.zip
# Downloaded 201200-10306316-calidad-aire-horario.zip
# Downloaded 201200-42-calidad-aire-horario.zip
# Downloaded 201200-10306314-calidad-aire-horario.zip
# Downloaded 201200-10306313-calidad-aire-horario.zip
# Downloaded 201200-28-calidad-aire-horario.zip
# Downloaded 201200-27-calidad-aire-horario.zip
# Downloaded 201200-26-calidad-aire-horario.zip
# Downloaded 201200-23-calidad-aire-horario.zip
# Downloaded 201200-22-calidad-aire-horario.zip
# Downloaded 201200-21-calidad-aire-horario.zip
# Downloaded 201200-20-calidad-aire-horario.zip
# Downloaded 201200-19-calidad-aire-horario.zip
# Downloaded 201200-18-calidad-aire-horario.zip
# Downloaded 201200-17-calidad-aire-horario.zip
# Downloaded 201200-16-calidad-aire-horario.zip
# Downloaded 201200-15-calidad-aire-horario.zip
# Downloaded 201200-14-calidad-aire-horario.zip
# Downloaded 201200-13-calidad-aire-horario.zip
# Downloaded 201200-30-calidad-aire-horario.zip
# Downloaded 201200-29-calidad-aire-horario.zip

# %% [markdown]
# ## Procesado de los archivos fuentes

# %% [markdown]
# Estaciones de medición

# %%
dataframe_list = []

for file in mediciones_estaciones:
    filepath = os.path.join(data_folder["estaciones"], file)
    df = pd.read_csv(filepath, sep=";")
    dataframe_list.append(df)

estaciones = pd.concat(dataframe_list)

# %%
estaciones.sample(10)
# Out:
#       CODIGO  CODIGO_CORTO         ESTACION  \
# 0   28079004             4  Plaza de España
# 13  28079047            47    Méndez Álvaro
# 22  28079059            59    Juan Carlos I
# 21  28079058            58         El Pardo
# 4   28079017            17       Villaverde
# 5   28079018            18        Farolillo
# 16  28079050            50   Plaza Castilla
# 18  28079055            55    Urb. Embajada
# 9   28079036            36        Moratalaz
# 14  28079048            48       Castellana
#
#                                             DIRECCION LONGITUD_ETRS89  \
# 0                                     Plaza de España    3°42'43.91"O
# 13  C/ Juan de Mariana / Plaza Amanecer Méndez Álvaro    3°41'12.57"O
# 22  Parque Juan Carlos I (frente oficinas mantenim...     3º 36' 33"O
# 21                                   Avda. La Guardia    3°46'28.62"O
# 4                                    C/ Juan Peñalver    3°42'47.89"O
# 5                           C/ Farolillo - C/ Ervigio    3°43'54.61"O
# 16                             Plaza Castilla (Canal)    3°41'19.48"O
# 18                                C/ Riaño (Barajas)     3°34'50.03"O
# 9       Avda. Moratalaz  esq. Camino de los Vinateros    3°38'43.02"O
# 14                          C/ José Gutiérrez Abascal    3°41'25.34"O
#
#    LATITUD_ETRS89  ALTITUD COD_TIPO        NOM_TIPO NO2  ...  BTX COD_VIA  \
# 0   40°25'25.98"N      637       UT  Urbana tráfico   X  ...  NaN  273600
# 13  40°23'53.17"N      600       UF    Urbana fondo   X  ...  NaN  414800
# 22  40º 27' 55''N      660        S       Suburbana   X  ...  NaN    1111
# 21   40°31'4.97"N      612        S       Suburbana   X  ...  NaN  348500
# 4   40°20'49.74"N      601       UF    Urbana fondo   X  ...  NaN  417200
# 5   40°23'41.22"N      632       UF    Urbana fondo   X  ...    X    1903
# 16  40°27'56.10"N      728       UT  Urbana tráfico   X  ...  NaN  154500
# 18  40°27'44.51"N      619       UF    Urbana fondo   X  ...    X  639250
# 9   40°24'28.64"N      671       UT  Urbana tráfico   X  ...  NaN  522000
# 14  40°26'23.61"N      680       UT  Urbana tráfico   X  ...  NaN  401400
#
#    VIA_CLASE VIA_PAR              VIA_NOMBRE  Fecha alta  COORDENADA_X_ETRS89  \
# 0      PLAZA      DE                  ESPAÑA  01/12/1998          439579,3291
# 13     CALLE      DE         JUAN DE MARIANA  21/12/2009          441715,4303
# 22       NaN     NaN                     NaN  14/12/2009          447744,4666
# 21   AVENIDA   DE LA                 GUARDIA  01/12/2009             434381,6
# 4      CALLE      DE           JUAN PEÑALVER  01/12/1998          439420,7015
# 5      CALLE     DEL               FAROLILLO  31/03/2001          437891,6961
# 16     PLAZA      DE                CASTILLA  01/02/2010          441609,9474
# 18     CALLE      DE                   RIAÑO  20/01/2010          450778,8839
# 9    AVENIDA      DE               MORATALAZ  01/12/1998           445245,513
# 14     CALLE      DE  JOSE GUTIERREZ ABASCAL  01/02/2010          441449,6341
#
#    COORDENADA_Y_ETRS89  LONGITUD    LATITUD
# 0          4475049,263 -3.712257  40.423882
# 13         4472170,249 -3.686814  40.398099
# 22         4479077,678 -3.616341  40.460726
# 21           4485548,7 -3.774610  40.518070
# 4          4466532,455 -3.713317  40.347147
# 5          4471832,769 -3.731836  40.394782
# 16         4479662,346 -3.688745  40.465584
# 18         4479238,863 -3.580565  40.462363
# 9          4473237,349 -3.645310  40.407952
# 14          4476811,42 -3.690373  40.439890
#
# [10 rows x 25 columns]

# %%
print(f"El dataset está compuesto por {estaciones.shape[0]} filas (es decir, observaciones) y {estaciones.shape[1]} columnas (es decir, atributos)")
# Out:
# El dataset está compuesto por 24 filas (es decir, observaciones) y 25 columnas (es decir, atributos)

# %%
filename = os.path.join(data_folder["estaciones"], "estaciones.csv")
estaciones.to_csv(filename, sep=";", index=False)

# %% [markdown]
# Mediciones diarias

# %%
dataframe_list = []

for file in mediciones_diarias:
    filepath = os.path.join(data_folder["diarios"], file)
    df = pd.read_csv(filepath, sep=";")
    dataframe_list.append(df)

calidad_d = pd.concat(dataframe_list)

# %%
calidad_d.sample(10)
# Out:
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD  PUNTO_MUESTREO   ANO  MES  \
# 215          28         79        11         7    28079011_7_8  2012    6
# 79           28         79         8         6   28079008_6_48  2012    8
# 1569         28         79        56         9   28079056_9_47  2019   10
# 586          28         79        24        42   28079024_42_2  2003   11
# 1142         28         79        47         8    28079047_8_8  2018    9
# 916          28         79        38         7    28079038_7_8  2018   11
# 1187         28         79        47         9   28079047_9_47  2010   10
# 1011         28         79        38        20  28079038_20_59  2011    4
# 1784         28         79        60        10  28079060_10_47  2013    9
# 655          28         79        24        35  28079024_35_59  2014    2
#
#         D01 V01    D02  ...    D27  V27     D28  V28   D29  V29    D30  V30  \
# 215   14.00   V   6.00  ...  36.00    V    8.00    V   7.0    V   7.00    V
# 79     0.30   V   0.40  ...   0.40    V    0.40    V   0.3    V   0.30    V
# 1569  11.00   V   6.00  ...  15.00    V   20.00    V  35.0    V  23.00    V
# 586    1.28   V   1.43  ...   1.29    V    1.32    V   1.3    V   1.28    V
# 1142  29.00   V  23.00  ...  41.00    V   59.00    V  54.0    V  46.00    V
# 916   23.00   V  14.00  ...  44.00    V  132.00    V  70.0    V  44.00    V
# 1187  16.00   V  16.00  ...  26.00    V   31.00    V  19.0    V   4.00    V
# 1011   7.20   V   3.20  ...   3.60    V    4.60    V   3.2    V   0.90    V
# 1784  23.00   V  24.00  ...  34.00    V   23.00    V  10.0    V  14.00    V
# 655    0.10   V   0.10  ...   0.10    V    0.10    V   0.0    N   0.00    N
#
#       D31  V31
# 215   0.0    N
# 79    0.3    V
# 1569  9.0    V
# 586   0.0    N
# 1142  0.0    N
# 916   0.0    N
# 1187  5.0    V
# 1011  0.0    N
# 1784  0.0    N
# 655   0.0    N
#
# [10 rows x 69 columns]

# %%
print(f"El dataset está compuesto por {calidad_d.shape[0]} filas (es decir, observaciones) y {calidad_d.shape[1]} columnas (es decir, atributos)")
# Out:
# El dataset está compuesto por 31396 filas (es decir, observaciones) y 69 columnas (es decir, atributos)

# %%
filename = os.path.join(data_folder["diarios"], "mediciones_diarias.csv")
calidad_d.to_csv(filename, sep=";", index=False)

# %% [markdown]
# Mediciones horarias

# %%
for file in mediciones_hora:
    filepath = os.path.join(data_folder["horarios"], file)
    with zipfile.ZipFile(filepath, mode="r") as archive:
        for file in archive.namelist():
            if file.endswith(".csv"):
                archive.extract(file, data_folder["horarios"])

files = glob.glob(data_folder["horarios"] + "/**/*.csv", recursive=True)

dataframe_list = []

for file in files:
    df = pd.read_csv(file, sep=";")
    dataframe_list.append(df)

calidad_h = pd.concat(dataframe_list)

# %%
calidad_h.sample(20)
# Out:
#         PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD  PUNTO_MUESTREO   ANO  MES  \
# 831331         28         79        38         9   28079038_9_47  2020   10
# 458186         28         79        24        10  28079024_10_47  2002    6
# 2719           28         79        39        14   28079039_14_6  2020    5
# 1827           28         79        38         7    28079038_7_8  2021    6
# 4101           28         79        57         6   28079057_6_48  2014   12
# 39035          28         79        58         7    28079058_7_8  2013    4
# 802958         28         79        36         1   28079036_1_38  2014   10
# 354            28         79        16        12   28079016_12_8  2002    8
# 1484           28         79        24        30  28079024_30_59  2021    3
# 632159         28         79        39         6   28079039_6_48  2010    5
# 156604         28         79         8         8    28079008_8_8  2003   12
# 4653           28         79        60        10  28079060_10_47  2011    7
# 891696         28         79        18        30  28079018_30_59  2017    9
# 658710         28         79        18        10  28079018_10_47  2016    5
# 1466           28         79        36         1   28079036_1_38  2001    4
# 1685           28         79        35         6   28079035_6_48  2009    3
# 722580         28         79        38        35  28079038_35_59  2013   11
# 595692         28         79        24        20  28079024_20_59  2019    3
# 1494           28         79        24        30  28079024_30_59  2020    4
# 180424         28         79        16        14   28079016_14_6  2011   12
#
#         DIA    H01 V01  ...    H20 V20     H21 V21     H22 V22     H23 V23  \
# 831331   30   7.00   V  ...  23.00   V   17.00   V   25.00   V   21.00   V
# 458186    4  13.00   V  ...  28.00   V   46.00   V   12.00   V   34.00   V
# 2719     10  82.21   V  ...  70.73   V   70.64   V   66.15   V   63.42   V
# 1827      2   1.00   V  ...   5.00   V    5.00   V    7.00   V    5.00   V
# 4101     15   0.20   V  ...   0.30   V    0.70   V    1.00   V    0.90   V
# 39035    28   1.00   V  ...   1.00   V    1.00   V    1.00   V    1.00   V
# 802958   16   2.00   V  ...   2.00   V    2.00   V    4.00   V    3.00   V
# 354      14  43.00   V  ...  94.00   V  176.00   V  330.00   V  152.00   V
# 1484     28   0.40   V  ...   0.20   V    0.20   V    0.20   V    0.30   V
# 632159   28   0.20   V  ...   0.20   V    0.30   V    0.30   V    0.30   V
# 156604    9  56.00   V  ...  84.00   V   86.00   V   78.00   V   74.00   V
# 4653     19  39.00   V  ...   4.00   V   13.00   V   19.00   V   15.00   V
# 891696   30   1.10   V  ...   0.30   V    0.40   V    0.50   V    0.70   V
# 658710   14   5.00   V  ...  11.00   V    5.00   V    6.00   V    9.00   V
# 1466     18   9.00   V  ...  69.00   V   62.00   V   46.00   V   27.00   V
# 1685     12   0.40   V  ...   0.50   V    0.60   V    1.60   V    0.60   V
# 722580    8   0.50   V  ...   0.60   V    0.40   V    0.50   V    0.50   V
# 595692    7   0.10   V  ...   0.10   V    0.40   V    0.30   V    0.30   V
# 1494     15   0.20   V  ...   0.20   V    0.20   V    0.20   V    0.20   V
# 180424   14  24.26   V  ...   6.18   V    8.37   V    8.40   V   14.27   V
#
#            H24 V24
# 831331   19.00   V
# 458186   33.00   V
# 2719     61.45   V
# 1827      5.00   V
# 4101      0.80   V
# 39035     1.00   V
# 802958    2.00   V
# 354     165.00   V
# 1484      0.30   V
# 632159    0.30   V
# 156604   67.00   V
# 4653     17.00   V
# 891696    0.60   V
# 658710   10.00   V
# 1466     25.00   V
# 1685      0.50   V
# 722580    0.50   V
# 595692    0.30   V
# 1494      0.20   V
# 180424   20.04   V
#
# [20 rows x 56 columns]

# %%
print(f"El dataset está compuesto por {calidad_h.shape[0]} filas (es decir, observaciones) y {calidad_h.shape[1]} columnas (es decir, atributos)")
# Out:
# El dataset está compuesto por 1895258 filas (es decir, observaciones) y 56 columnas (es decir, atributos)

# %%
filename = os.path.join(data_folder["horarios"], "mediciones_horarias.csv")
calidad_h.to_csv(filename, sep=";", index=False)
